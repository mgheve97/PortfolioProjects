# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

df = pd.read_csv(r'C:\Files\Gheve\Programming\Data Analyst\nashville-datacleaning-project\Nashville Housing Data for Data Cleaning - Fixed.csv')

# %%
df.head(25)
# Out:
#     UniqueID           ParcelID                  LandUse  \
# 0           9   119 15 0 158.00            SINGLE FAMILY
# 1         208   081 02 0 085.00            SINGLE FAMILY
# 2         212   081 15 0 092.00            SINGLE FAMILY
# 3         239   070 02 0 028.00            SINGLE FAMILY
# 4         241   080 08 0 031.00            SINGLE FAMILY
# 5         284   082 03 0 032.00            SINGLE FAMILY
# 6         489  182 12 0A 134.00  VACANT RESIDENTIAL LAND
# 7         643   081 07 0 172.00            SINGLE FAMILY
# 8         644   081 07 0 381.00            SINGLE FAMILY
# 9         648   081 15 0 160.00            SINGLE FAMILY
# 10        656   092 05 0 325.00            SINGLE FAMILY
# 11        729   082 07 0 219.00  VACANT RESIDENTIAL LAND
# 12        969  182 12 0A 136.00  VACANT RESIDENTIAL LAND
# 13       1170   081 15 0 055.00            SINGLE FAMILY
# 14       1202   059 12 0 065.00                   DUPLEX
# ...

# %%
df.dtypes
# Out:
# UniqueID             int64
# ParcelID            object
# LandUse             object
# PropertyAddress     object
# SaleDate            object
# SalePrice            int64
# LegalReference      object
# SoldAsVacant        object
# OwnerName           object
# OwnerAddress        object
# Acreage            float64
# TaxDistrict         object
# LandValue          float64
# BuildingValue      float64
# TotalValue         float64
# YearBuilt          float64
# Bedrooms           float64
# FullBath           float64
# HalfBath           float64
# dtype: object

# %%
df.drop_duplicates().head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0          9  119 15 0 158.00  SINGLE FAMILY
# 1        208  081 02 0 085.00  SINGLE FAMILY
# 2        212  081 15 0 092.00  SINGLE FAMILY
# 3        239  070 02 0 028.00  SINGLE FAMILY
# 4        241  080 08 0 031.00  SINGLE FAMILY
#
#                      PropertyAddress   SaleDate  SalePrice    LegalReference  \
# 0           113  NEESE DR, NASHVILLE   1/9/2013      25000  20130111-0003850
# 1         1730  KELLOW ST, NASHVILLE  1/28/2013      27000  20130128-0008849
# 2         1902  HEIMAN ST, NASHVILLE  1/25/2013      25000  20130129-0009266
# 3  2816  BUENA VISTA PIKE, NASHVILLE  1/10/2013      26000  20130114-0004126
# 4          3239  CROWE DR, NASHVILLE  1/17/2013      27000  20130118-0006143
#
#   SoldAsVacant                     OwnerName  \
# 0           No             SONA LAND CO, LLC
# 1           No  HALL, BOBBY & POTEAT, PAMELA
# 2           No             BURKS, MICHELE J.
# ...

# %%
df.head(30)
# Out:
#     UniqueID           ParcelID                  LandUse  \
# 0           9   119 15 0 158.00            SINGLE FAMILY
# 1         208   081 02 0 085.00            SINGLE FAMILY
# 2         212   081 15 0 092.00            SINGLE FAMILY
# 3         239   070 02 0 028.00            SINGLE FAMILY
# 4         241   080 08 0 031.00            SINGLE FAMILY
# 5         284   082 03 0 032.00            SINGLE FAMILY
# 6         489  182 12 0A 134.00  VACANT RESIDENTIAL LAND
# 7         643   081 07 0 172.00            SINGLE FAMILY
# 8         644   081 07 0 381.00            SINGLE FAMILY
# 9         648   081 15 0 160.00            SINGLE FAMILY
# 10        656   092 05 0 325.00            SINGLE FAMILY
# 11        729   082 07 0 219.00  VACANT RESIDENTIAL LAND
# 12        969  182 12 0A 136.00  VACANT RESIDENTIAL LAND
# 13       1170   081 15 0 055.00            SINGLE FAMILY
# 14       1202   059 12 0 065.00                   DUPLEX
# ...

# %%
df.head(3)
# Out:
#    UniqueID          ParcelID        LandUse             PropertyAddress  \
# 0          9  119 15 0 158.00  SINGLE FAMILY    113  NEESE DR, NASHVILLE
# 1        208  081 02 0 085.00  SINGLE FAMILY  1730  KELLOW ST, NASHVILLE
# 2        212  081 15 0 092.00  SINGLE FAMILY  1902  HEIMAN ST, NASHVILLE
#
#     SaleDate  SalePrice    LegalReference SoldAsVacant  \
# 0   1/9/2013      25000  20130111-0003850           No
# 1  1/28/2013      27000  20130128-0008849           No
# 2  1/25/2013      25000  20130129-0009266           No
#
#                       OwnerName                    OwnerAddress  Acreage  \
# 0             SONA LAND CO, LLC    113  NEESE DR, NASHVILLE, TN     0.40
# 1  HALL, BOBBY & POTEAT, PAMELA  1730  KELLOW ST, NASHVILLE, TN     0.17
# 2             BURKS, MICHELE J.  1902  HEIMAN ST, NASHVILLE, TN     0.15
#
#                TaxDistrict  LandValue  BuildingValue  TotalValue  YearBuilt  \
# ...

# %%
plt.scatter(x=df['SalePrice'], y=df['LandValue'])
plt.title('Sales Price vs Land Value')
plt.xlabel('Price of Sales')
plt.ylabel('value of the Land')
plt.show()

# %%
sns.regplot(x='SalePrice', y='LandValue', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot: xlabel='SalePrice', ylabel='LandValue'>

# %%
df.corr(method='pearson')
# Out:
# C:\Users\MyComputer\AppData\Local\Temp\ipykernel_13436\1928163937.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#                UniqueID   SalePrice   Acreage  LandValue  BuildingValue  \
# UniqueID        1.000000   0.017630  0.000504  -0.055119      -0.080458
# SalePrice       0.017630   1.000000  0.201187   0.603651       0.574637
# Acreage         0.000504   0.201187  1.000000   0.295975       0.127164
# LandValue      -0.055119   0.603651  0.295975   1.000000       0.516283
# BuildingValue  -0.080458   0.574637  0.127164   0.516283       1.000000
# TotalValue     -0.081099   0.661753  0.210080   0.765872       0.945600
# YearBuilt       0.006831   0.037252  0.018346  -0.015531       0.194773
# Bedrooms       -0.040758   0.372746  0.150528   0.342005       0.447465
# ...

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric features')
plt.xlabel('NashVille')
plt.show()
# Out:
# C:\Users\MyComputer\AppData\Local\Temp\ipykernel_13436\3355982230.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method='pearson')
